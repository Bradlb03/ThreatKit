# %%
pip install --no-cache-dir yara-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.9 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yara
print("yara-python version:", yara.__version__)
# Out:
# yara-python version: 4.5.4

# %%
# %%bash
# set -e
# mkdir -p tests/synthetic
#
# # For packed rule
# echo 'Hello… this mentions UPX! and .UPX so it should match' > tests/synthetic/fake_upx.txt
#
# # For suspicious APIs rule
# cat > tests/synthetic/fake_apis.txt <<'TXT'
# We call VirtualAlloc and then CreateRemoteThread in this pretend example.
# TXT
#
# # For malware keywords rule
# echo 'user installed hacktool under C:\Users\X\AppData\Roaming\Tools' > tests/synthetic/fake_keywords.txt
#
# ls -l tests/synthetic
# Out:
# total 12
# -rw-r--r-- 1 jovyan users 74 Oct 13 23:14 fake_apis.txt
# -rw-r--r-- 1 jovyan users 63 Oct 13 23:14 fake_keywords.txt
# -rw-r--r-- 1 jovyan users 56 Oct 13 23:14 fake_upx.txt

# %%
# !yara -v
# Out:
# 4.1.3

# %%
# !yarac -v
# Out:
# 4.1.3

# %%
# !ls -l /home/jovyan/work/malware/rules/
# Out:
# total 4
# -rw-r--r-- 1 jovyan users 605 Oct 13 23:10 initial_rules_test.yar

# %%
# compile to .yarc
# !yarac /home/jovyan/work/malware/rules/initial_rules_test.yar \
       /home/jovyan/work/malware/rules/initial_rules_test.yarc

yara -C -r /home/jovyan/work/malware/rules/initial_rules_test.yarc tests/synthetic
# Out:
# -rw-r--r-- 1 jovyan users 16026 Oct 13 23:39 /home/jovyan/work/malware/rules/initial_rules_test.yarc
# /home/jovyan/work/malware/rules/initial_rules_test.yarc(1): error: syntax error
# /home/jovyan/work/malware/rules/initial_rules_test.yarc(1): error: non-ascii character

# %%
# !yara -C -r /home/jovyan/work/malware/rules/initial_rules_test.yarc tests/synthetic
# Out:
# TEST_Suspicious_Win32_APIs tests/synthetic/fake_apis.txt
# TEST_Malware_Keywords tests/synthetic/fake_keywords.txt
# TEST_Packed_UPX_or_ASPack tests/synthetic/fake_upx.txt
