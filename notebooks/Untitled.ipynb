# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.__version__, np.__version__
# Out:
# ('2.1.1', '1.24.4')

# %%
pd.DataFrame({"x": range(5), "y": np.random.randn(5)}).plot(x="x", y="y")
plt.show()
